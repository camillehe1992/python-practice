# %% [markdown]
# ## AKShare
#
# AKShare is an elegant and simple financial data interface library for Python, built for human beings!
#
# https://github.com/akfamily/akshare
#
# Links:
# https://mp.weixin.qq.com/s/9y5ggFpK--C6sRXRcaKAww

# %%
## Install dependencies
# pip install akshare
# !python --version
# Out:
# Python 3.11.6

# %%
# Import package
import akshare as ak
import mplfinance as mpf
from datetime import datetime, timedelta

# %%
start_date = (datetime.today() - timedelta(days=30)).strftime("%Y%m%d")
end_date = datetime.today().strftime("%Y%m%d")

# 获取五粮液股票历史行情数据
stock_zh_a_hist_df = ak.stock_zh_a_hist(
    symbol="000858",
    period="daily",
    start_date=start_date,
    end_date=end_date,
    adjust="hfq",
)
stock_zh_a_hist_df
# Out:
#             日期       开盘       收盘       最高       最低     成交量           成交额  \
# 0   2024-04-15  2498.64  2603.73  2614.05  2490.20  254292  3.701904e+09
# 1   2024-04-16  2592.47  2566.98  2601.23  2556.66  135678  1.976125e+09
# 2   2024-04-17  2560.10  2572.14  2575.90  2548.69  137023  1.982007e+09
# 3   2024-04-18  2552.91  2567.14  2595.29  2540.87  152453  2.213439e+09
# 4   2024-04-19  2551.50  2534.61  2559.63  2520.38  127262  1.818608e+09
# 5   2024-04-22  2534.61  2560.57  2590.60  2534.61  140366  2.035477e+09
# 6   2024-04-23  2551.81  2599.20  2606.39  2551.35  171712  2.507418e+09
# 7   2024-04-24  2613.27  2629.69  2633.13  2583.09  142251  2.103883e+09
# 8   2024-04-25  2622.19  2629.69  2635.48  2599.04  100776  1.496359e+09
# 9   2024-04-26  2633.13  2680.83  2687.87  2633.13  179462  2.719514e+09
# 10  2024-04-29  2661.28  2673.01  2748.23  2645.80  275385  4.217464e+09
# 11  2024-04-30  2681.61  2652.37  2700.22  2652.37  155296  2.359135e+09
# 12  2024-05-06  2699.44  2723.99  2775.91  2698.81  316796  4.940155e+09
# 13  2024-05-07  2723.84  2738.54  2746.04  2701.16  145500  2.265634e+09
# 14  2024-05-08  2739.16  2723.84  2744.48  2713.67  101074  1.567926e+09
# 15  2024-05-09  2713.36  2721.33  2734.63  2703.98  113275  1.750315e+09
# 16  2024-05-10  2723.84  2714.92  2737.75  2689.43  102514  1.579216e+09
# 17  2024-05-13  2689.43  2662.85  2692.25  2649.87  172628  2.608851e+09
# 18  2024-05-14  2662.85  2666.60  2674.58  2646.11  113455  1.713074e+09
# 19  2024-05-15  2666.44  2672.23  2674.26  2653.46   72487  1.096565e+09
#
#       振幅   涨跌幅     涨跌额   换手率
# 0   4.96  4.28  106.81  0.66
# 1   1.71 -1.41  -36.75  0.35
# 2   1.06  0.20    5.16  0.35
# 3   2.12 -0.19   -5.00  0.39
# 4   1.53 -1.27  -32.53  0.33
# 5   2.21  1.02   25.96  0.36
# 6   2.15  1.51   38.63  0.44
# 7   1.93  1.17   30.49  0.37
# 8   1.39  0.00    0.00  0.26
# 9   2.08  1.94   51.14  0.46
# 10  3.82 -0.29   -7.82  0.71
# 11  1.79 -0.77  -20.64  0.40
# 12  2.91  2.70   71.62  0.82
# 13  1.65  0.53   14.55  0.37
# 14  1.13 -0.54  -14.70  0.26
# 15  1.13 -0.09   -2.51  0.29
# 16  1.78 -0.24   -6.41  0.26
# 17  1.56 -1.92  -52.07  0.44
# 18  1.07  0.14    3.75  0.29
# 19  0.78  0.21    5.63  0.19

# %%
# 获取上交易所和深交所的数据总览

stack_sse_summary_df = ak.stock_sse_summary()
stack_sse_summary_df
# Out:
#       项目         股票         主板       科创板
# 0   流通股本   45630.76   44291.17    1339.6
# 1    总市值  488993.03  436247.13  52745.89
# 2  平均市盈率      13.42      12.63     35.90
# 3   上市公司       2273       1701       572
# 4   上市股票       2312       1740       572
# 5   流通市值  451487.76  414853.39  36634.37
# 6   报告时间   20240514   20240514  20240514
# 8    总股本   49199.86   47057.23   2142.63
